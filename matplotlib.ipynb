# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
####    1 Line Chart

# %%
ls = [41,52,65,60]
plt.plot(ls)

# %%
#### 2. Scatter plot    in this we use 2 numeric column

# %%
df = pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name   price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1           Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                  Triumph Daytona 675R  600000      Delhi         110
# 3                  TVS Apache RTR 180cc   65000  Bangalore       16329
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
#
#          owner  age  power          brand
# 0  First Owner    3    110            TVS
# 1  First Owner    4    350  Royal Enfield
# 2  First Owner    8    675        Triumph
# 3  First Owner    4    180            TVS
# 4  First Owner    3    150         Yamaha

# %%
ls1 = [25,35,68,24,61]
ls2 = [96,45,12,36,45]
plt.scatter(x=ls1,y=ls2,marker='*',s=200,color='red')
plt.ylabel("ls2")
plt.xlabel("ls1")
plt.title("scatter plot ")
plt.show()

# %%
df
# Out:
#                                   bike_name   price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1               Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                      Triumph Daytona 675R  600000      Delhi         110
# 3                      TVS Apache RTR 180cc   65000  Bangalore       16329
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                     ...     ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000      Delhi       22000
# 32644                  TVS Apache RTR 180cc   30000     Karnal        6639
# 32645              Bajaj Avenger Street 220   60000      Delhi       20373
# 32646             Hero Super Splendor 125cc   15600     Jaipur       84186
# 32647                    Bajaj Pulsar 150cc   22000       Pune       60857
#
#              owner  age  power          brand
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
plt.scatter(x=df['kms_driven'],y=df['price'])
plt.xlabel('kms_driven')
plt.ylabel('price')
plt.show()

# %%
import numpy as np 
arr1 = np.random.randint(1,200,500)

# %%
arr2 = arr1 * 50

# %%
plt.scatter(arr1,arr2)
plt.xlabel('arr - 1')          # x^| y^ = +ve
plt.ylabel('arr -2')           # x | y^ = -ve relationship
plt.show()

# %%
### 3. Histogram

# %%
age = np.random.randint(1,100,1000) 
age
# Out:
# array([49, 70, 52, 18, 50, 56, 43, 75, 32, 71, 10, 73, 68, 78, 36, 52, 95,
#        50, 30, 56,  4, 71, 68, 15, 22, 17, 34, 12, 34, 23, 53, 98, 91, 35,
#        21, 28, 29, 31,  3, 41, 72, 39, 55, 82,  8,  2, 43, 10, 90, 59, 29,
#        51, 26, 83, 44, 38, 46, 35, 22, 75,  6, 37, 20, 56, 67, 46,  7, 69,
#         7, 55, 22, 26, 88, 14, 86, 74, 96, 79, 79, 55, 13, 14, 69, 39, 31,
#        55, 96,  4, 74, 97, 45, 49, 75, 92, 72, 67, 50, 51, 39, 54,  4, 35,
#        65, 11, 21, 72, 35, 53,  2, 56, 66, 87, 89, 43, 81, 98, 97, 84, 82,
#        21, 49, 81, 65, 88, 98, 87, 50, 93, 24, 67, 68, 19, 32, 48, 77, 71,
#        62, 57, 62, 32, 70, 94,  2, 90, 24, 76, 71, 98, 71, 35, 50, 43, 27,
#        31, 19, 96, 65, 99, 93,  1, 75, 33, 13, 55, 49, 88, 33, 52, 48, 90,
#        35, 30, 39, 14, 77, 44, 88, 49, 90, 27,  9,  9, 51, 51, 81, 11,  1,
#        59, 50, 33, 40, 68, 59, 19, 88, 21, 71, 20, 32, 10, 26, 67, 38, 48,
# ...

# %%
bucket = [ 0,18,30,50,70,90,110 ] 
plt.hist(age, bins = bucket ,ec ='k', color='red')  #bins, #ec= k
plt.show()

# %%
bucket = [ 0,18,30,50,70,90,110 ] 
plt.hist(age ,ec ='k')  
plt.show()

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
df['price'].min()
# Out:
# 4400

# %%
df['price'].max()
# Out:
# 1900000

# %%
age
# Out:
# array([49, 70, 52, 18, 50, 56, 43, 75, 32, 71, 10, 73, 68, 78, 36, 52, 95,
#        50, 30, 56,  4, 71, 68, 15, 22, 17, 34, 12, 34, 23, 53, 98, 91, 35,
#        21, 28, 29, 31,  3, 41, 72, 39, 55, 82,  8,  2, 43, 10, 90, 59, 29,
#        51, 26, 83, 44, 38, 46, 35, 22, 75,  6, 37, 20, 56, 67, 46,  7, 69,
#         7, 55, 22, 26, 88, 14, 86, 74, 96, 79, 79, 55, 13, 14, 69, 39, 31,
#        55, 96,  4, 74, 97, 45, 49, 75, 92, 72, 67, 50, 51, 39, 54,  4, 35,
#        65, 11, 21, 72, 35, 53,  2, 56, 66, 87, 89, 43, 81, 98, 97, 84, 82,
#        21, 49, 81, 65, 88, 98, 87, 50, 93, 24, 67, 68, 19, 32, 48, 77, 71,
#        62, 57, 62, 32, 70, 94,  2, 90, 24, 76, 71, 98, 71, 35, 50, 43, 27,
#        31, 19, 96, 65, 99, 93,  1, 75, 33, 13, 55, 49, 88, 33, 52, 48, 90,
#        35, 30, 39, 14, 77, 44, 88, 49, 90, 27,  9,  9, 51, 51, 81, 11,  1,
#        59, 50, 33, 40, 68, 59, 19, 88, 21, 71, 20, 32, 10, 26, 67, 38, 48,
# ...

# %%
##### 4 . BOX PLOT
 # it tell  
 #1 min value
 #2.max value
 #3.median 
 #4.

# %%
plt.boxplot(age)
plt.show()

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
plt.boxplot(df[df["brand"] == "Bajaj"]['price'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[df["brand"] == "Bajaj"]['price'].max()
# Out:
# 195000
